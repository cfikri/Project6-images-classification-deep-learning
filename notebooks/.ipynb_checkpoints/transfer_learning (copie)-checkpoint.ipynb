# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import mlflow
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.utils import set_random_seed
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.applications import VGG16, InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from time import time

# %cd ..
import src.mytools as mt
# %cd notebooks
# Out:
# /home/chakir/Bureau/PROJETS/Projet6
# /home/chakir/Bureau/PROJETS/Projet6/notebooks

# %%
# Chemin vers les dossiers 'train', 'validation' et 'test'
train_dir = '../data/train'
val_dir = '../data/validation'
test_dir = '../data/test'

class_names = os.listdir(val_dir)

# %%
# Fixation des sources des générateurs aléatoires pour assurer la reproductibilité des résultats.
seed_value = 42
set_random_seed(seed_value)

# %%
mlflow.set_tracking_uri("http://ec2-52-209-5-80.eu-west-1.compute.amazonaws.com:5000")
mlflow.set_experiment('projet6_transfer-learning')
# Out:
# 2024/07/17 18:57:53 INFO mlflow.tracking.fluent: Experiment with name 'projet6_transfer-learning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-cfikri/937544924322822054', creation_time=1721235473336, experiment_id='937544924322822054', last_update_time=1721235473336, lifecycle_stage='active', name='projet6_transfer-learning', tags={}>

# %% [markdown]
# ### GÉNÉRATEUR DE DONNÉES

# %%
# Définition des générateurs de données

t_generator = ImageDataGenerator(rescale=1./255,
                                 rotation_range=40,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 zoom_range=0.4,
                                 horizontal_flip=True,
                                 fill_mode='nearest'
                                )

generator = ImageDataGenerator(rescale=1./255)

train_generator = t_generator.flow_from_directory(train_dir,
                                                  target_size=(256, 256),
                                                  class_mode='categorical',
                                                  seed=seed_value
                                                 )

val_generator = generator.flow_from_directory(val_dir,
                                              target_size=(256, 256),
                                              class_mode='categorical',
                                              shuffle=False,
                                              seed=seed_value
                                             )
# Out:
# Found 288 images belonging to 3 classes.
# Found 72 images belonging to 3 classes.

# %% [markdown]
# ### VGG16

# %%
# Chargement du modèle VGG16 pré-entraîné sans les couches supérieures
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Fixation des couches de base du modèle VGG16 pour ne pas les réentraîner
for layer in base_model.layers:
    layer.trainable = False

# %%
# Ajouter vos propres couches de classification
model = Sequential([base_model,
                    Flatten(),
                    Dense(512, activation='relu'),
                    Dense(3, activation='softmax')
                   ])

# %%
history, temps_execution = mt.compile_and_train(model, train_generator, val_generator, optimizer=Nadam, epochs=100)
print(f"durée d'exécution : {temps_execution} min")
# Out:
# Epoch 1/100
# /home/chakir/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-07-17 18:58:44.248052: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 536870912 exceeds 10% of free system memory.
# 2024-07-17 18:58:44.511971: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 536870912 exceeds 10% of free system memory.
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 1:22 10s/step - accuracy: 0.3750 - auc: 0.5100 - loss: 1.4281 - precision: 0.3750 - recall: 0.3750
# 2024-07-17 18:58:49.663623: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 536870912 exceeds 10% of free system memory.
# 2024-07-17 18:58:49.924504: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 536870912 exceeds 10% of free system memory.
# 2/9 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.3828 - auc: 0.5268 - loss: 8.5125 - precision: 0.3828 - recall: 0.3828
# 2024-07-17 18:58:55.204889: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 536870912 exceeds 10% of free system memory.
# 9/9 ━━━━━━━━━━━━━━━━━━━━
100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8902 - auc: 0.9814 - loss: 0.2650 - precision: 0.9012 - recall: 0.8826 - val_accuracy: 0.9028 - val_auc: 0.9885 - val_loss: 0.2023 - val_precision: 0.9155 - val_recall: 0.9028 - learning_rate: 0.0010
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8804 - auc: 0.9740 - loss: 0.3092 - precision: 0.8870 - recall: 0.8728 - val_accuracy: 0.8889 - val_auc: 0.9898 - val_loss: 0.1881 - val_precision: 0.9014 - val_recall: 0.8889 - learning_rate: 0.0010
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8895 - auc: 0.9775 - loss: 0.2850 - precision: 0.8988 - recall: 0.8761 - val_accuracy: 0.9167 - val_auc: 0.9813 - val_loss: 0.2658 - val_precision: 0.9155 - val_recall: 0.9028 - learning_rate: 0.0010
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8845 - auc: 0.9794 - loss: 0.2746 - precision: 0.8918 - recall: 0.8803 - val_accuracy: 0.9167 - val_auc: 0.9867 - val_loss: 0.2298 - val_precision: 0.9155 - val_recall: 0.9028 - learning_rate: 0.0010
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8962 - auc: 0.9860 - loss: 0.2350 - precision: 0.9116 - recall: 0.8929 - val_accuracy: 0.9028 - val_auc: 0.9857 - val_loss: 0.2413 - val_precision: 0.9286 - val_recall: 0.9028 - learning_rate: 0.0010
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.9051 - auc: 0.9856 - loss: 0.2301 - precision: 0.9212 - recall: 0.8960 - val_accuracy: 0.8472 - val_auc: 0.9494 - val_loss: 0.4680 - val_precision: 0.8472 - val_recall: 0.8472 - learning_rate: 0.0010
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 74s 8s/step - accuracy: 0.9076 - auc: 0.9831 - loss: 0.2452 - precision: 0.9104 - recall: 0.8904 - val_accuracy: 0.9028 - val_auc: 0.9828 - val_loss: 0.2575 - val_precision: 0.9130 - val_recall: 0.8750 - learning_rate: 0.0010
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.8810 - auc: 0.9845 - loss: 0.2336 - precision: 0.8934 - recall: 0.8803 - val_accuracy: 0.8889 - val_auc: 0.9789 - val_loss: 0.3015 - val_precision: 0.8873 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.9101 - auc: 0.9872 - loss: 0.2157 - precision: 0.9136 - recall: 0.9045 - val_accuracy: 0.8889 - val_auc: 0.9849 - val_loss: 0.2304 - val_precision: 0.9130 - val_recall: 0.8750 - learning_rate: 5.0000e-04
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 74s 8s/step - accuracy: 0.9052 - auc: 0.9864 - loss: 0.2227 - precision: 0.9105 - recall: 0.9019 - val_accuracy: 0.8889 - val_auc: 0.9827 - val_loss: 0.2710 - val_precision: 0.9014 - val_recall: 0.8889 - learning_rate: 5.0000e-04
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.9329 - auc: 0.9910 - loss: 0.1914 - precision: 0.9335 - recall: 0.9202 - val_accuracy: 0.9167 - val_auc: 0.9863 - val_loss: 0.2425 - val_precision: 0.9143 - val_recall: 0.8889 - learning_rate: 5.0000e-04
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 75s 8s/step - accuracy: 0.9154 - auc: 0.9902 - loss: 0.1985 - precision: 0.9258 - recall: 0.9143 - val_accuracy: 0.8889 - val_auc: 0.9833 - val_loss: 0.2700 - val_precision: 0.9014 - val_recall: 0.8889 - learning_rate: 5.0000e-04
# durée d'exécution : 43 min

# %%
mt.graphique_auc_perte(history, 'VGG16')

# %%
mt.matrice_confusion(model, 'VGG16', val_generator, class_names)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step

# %%
params = {'algorithme' : 'VGG16',  
          'optimizer' : 'Nadam', 
          'fonction_perte' : 'categorical_crossentropy',
          'learning_rate' : 0.001,
          'nbr_epoques' : 100}

metrics = {'accuracy' : max(history.history['val_accuracy']),
           'precision' : max(history.history['val_precision']),
           'recall' : max(history.history['val_recall']),
           'auc-roc' : max(history.history['val_auc'])}

tags = {'Dataset' : 'Stanford Dogs Dataset', 'algorithme' : 'VGG16'}

artifacts = {"Evolution du AUC-ROC et de l'entropie croisée au cours des époques" : '../outputs/courbes_performances_VGG16.png',
             'Matrice de confusion' : '../outputs/matrice_confusion_VGG16.png'}

mt.log_mlflow_run('VGG16_transfer_learning', 
                  params, 
                  metrics, 
                  tags=tags, 
                  artifacts=artifacts,
                  model=model,
                  model_type='tensorflow',
                  model_name='VGG16')
# Out:
# 2024/07/17 19:57:16 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# /home/chakir/anaconda3/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ### INCEPTIONV3

# %%
# Charger le modèle InceptionV3 pré-entraîné sans les couches supérieures
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Geler les couches de base du modèle InceptionV3 pour ne pas les entraîner
for layer in base_model.layers:
    layer.trainable = False

# %%
# Ajouter vos propres couches de classification
model = Sequential([base_model,
                    Flatten(),
                    Dense(512, activation='relu'),
                    Dense(3, activation='softmax')
                   ])

# %%
history, temps_execution = mt.compile_and_train(model, train_generator, val_generator, optimizer=Nadam, epochs=100)
print(f"durée d'exécution : {temps_execution} min")
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.5230 - auc: 0.6649 - loss: 43.9125 - precision: 0.5256 - recall: 0.5139 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 8.4686e-05 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9707 - auc: 0.9817 - loss: 0.6477 - precision: 0.9707 - recall: 0.9707 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.5534 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 0.0010
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9681 - auc: 0.9849 - loss: 0.5758 - precision: 0.9681 - recall: 0.9681 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.1913 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 0.0010
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9688 - auc: 0.9858 - loss: 0.3705 - precision: 0.9688 - recall: 0.9688 - val_accuracy: 0.9861 - val_auc: 0.9895 - val_loss: 0.6537 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 0.0010
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9550 - auc: 0.9692 - loss: 0.6782 - precision: 0.9550 - recall: 0.9550 - val_accuracy: 0.9861 - val_auc: 0.9895 - val_loss: 0.6676 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 0.0010
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9867 - auc: 0.9938 - loss: 0.1365 - precision: 0.9867 - recall: 0.9867 - val_accuracy: 0.9861 - val_auc: 0.9895 - val_loss: 0.1839 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 0.0010
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9739 - auc: 0.9844 - loss: 0.2684 - precision: 0.9739 - recall: 0.9739 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 4.0443e-06 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9828 - auc: 0.9966 - loss: 0.1376 - precision: 0.9828 - recall: 0.9828 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 5.6132e-05 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9798 - auc: 0.9941 - loss: 0.1321 - precision: 0.9798 - recall: 0.9798 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0010 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9745 - auc: 0.9827 - loss: 0.3286 - precision: 0.9745 - recall: 0.9745 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.6036e-05 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9827 - auc: 0.9878 - loss: 0.2482 - precision: 0.9827 - recall: 0.9827 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.2760 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 5.0000e-04
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9859 - auc: 0.9893 - loss: 0.2945 - precision: 0.9859 - recall: 0.9859 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.3137 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 2.5000e-04
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9755 - auc: 0.9836 - loss: 0.6217 - precision: 0.9755 - recall: 0.9755 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.3770 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 2.5000e-04
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9985 - auc: 1.0000 - loss: 0.0031 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.2686 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 2.5000e-04
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9811 - auc: 0.9899 - loss: 0.1650 - precision: 0.9811 - recall: 0.9811 - val_accuracy: 0.9861 - val_auc: 0.9999 - val_loss: 0.0698 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 2.5000e-04
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9494 - auc: 0.9706 - loss: 1.9000 - precision: 0.9494 - recall: 0.9494 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.4576 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 2.5000e-04
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9787 - auc: 0.9873 - loss: 0.2923 - precision: 0.9787 - recall: 0.9787 - val_accuracy: 0.9861 - val_auc: 0.9896 - val_loss: 0.2456 - val_precision: 0.9861 - val_recall: 0.9861 - learning_rate: 1.2500e-04
# durée d'exécution : 7 min

# %%
mt.graphique_auc_perte(history, 'InceptionV3')

# %%
mt.matrice_confusion(model, 'InceptionV3', val_generator, class_names)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step

# %%
params = {'algorithme' : 'InceptionV3',  
          'optimizer' : 'Nadam', 
          'fonction_perte' : 'categorical_crossentropy',
          'learning_rate' : 0.001,
          'nbr_epoques' : 100}

metrics = {'accuracy' : max(history.history['val_accuracy']),
           'precision' : max(history.history['val_precision']),
           'recall' : max(history.history['val_recall']),
           'auc-roc' : max(history.history['val_auc'])}

tags = {'Dataset' : 'Stanford Dogs Dataset', 'algorithme' : 'InceptionV3'}

artifacts = {"Evolution du AUC-ROC et de l'entropie croisée au cours des époques" : '../outputs/courbes_performances_InceptionV3.png',
             'Matrice de confusion' : '../outputs/matrice_confusion_InceptionV3.png'}

mt.log_mlflow_run('InceptionV3_transfer_learning', 
                  params, 
                  metrics, 
                  tags=tags, 
                  artifacts=artifacts,
                  model=model,
                  model_type='tensorflow',
                  model_name='InceptionV3')
# Out:
# 2024/07/17 20:37:21 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.

# %%
test_generator = generator.flow_from_directory(test_dir,
                                               target_size=(256, 256),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=seed_value
                                              )
# Out:
# Found 91 images belonging to 3 classes.

# %%
mt.matrice_confusion(model, 'InceptionV3_test', test_generator, class_names)
# Out:
# /home/chakir/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step

# %%
from tensorflow.keras.models import load_model
gilou = load_model('s3://mlflow-cfikri/937544924322822054/f154eae389294193aed012085329d82b/artifacts/InceptionV3')
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[46], line 2
#       1 from tensorflow.keras.models import load_model
# ----> 2 gilou = load_model('s3://mlflow-cfikri/937544924322822054/f154eae389294193aed012085329d82b/artifacts/InceptionV3')
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_api.py:168, in load_model(filepath, custom_objects, compile, safe_mode)
#     163 local_path = os.path.join(
#     164     saving_lib.get_temp_dir(), os.path.basename(filepath)
#     165 )
#     167 # Copy from remote to temporary local directory
# --> 168 file_utils.copy(filepath, local_path)
#     170 # Switch filepath to local zipfile for loading model
#     171 if zipfile.is_zipfile(local_path):
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/file_utils.py:478, in copy(src, dst)
#     476 if is_remote_path(src) or is_remote_path(dst):
#     477     if gfile.available:
# --> 478         return gfile.copy(src, dst, overwrite=True)
#     479     else:
#     480         _raise_if_no_gfile(f"src={src} dst={dst}")
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/lib/io/file_io.py:581, in copy_v2(src, dst, overwrite)
#     516 @tf_export("io.gfile.copy")
#     517 def copy_v2(src, dst, overwrite=False):
#     518   """Copies data from `src` to `dst`.
#     519
#     520   >>> with open("/tmp/x", "w") as f:
#    (...)
#     579     errors.OpError: If the operation fails.
#     580   """
# --> 581   _pywrap_file_io.CopyFile(
#     582       compat.path_to_bytes(src), compat.path_to_bytes(dst), overwrite)
#
# UnimplementedError: File system scheme 's3' not implemented (file: 's3://mlflow-cfikri/937544924322822054/f154eae389294193aed012085329d82b/artifacts/InceptionV3')
